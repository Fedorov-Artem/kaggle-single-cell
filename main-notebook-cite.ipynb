# %% [markdown]
# # **Main CITE Notebook**
#
# This is the main notebook for CITE part of the project, where the task is to predict normalized surface protein levels given information about library-size normalized and log1p transformed counts (gene expression levels) for the same cells.
#
# In this Jupyter notebook, data from several sources is joined together and is used further to either cross-validate or create predictions for the test dataset. The sources are:
# 1. pre-calculated Truncated SVD values from all the RNA expression levels data (see Prepare_SVD_for_CITE notebook)
# 2. source data for RNA gene expression levels - for pre-selected important genes this data is going to be put into the model as is
# 3. metadata - cells' donor ID and day the cells were analyzed. Few features are built from metadata information.
# 4. target values for the train set

# %%
# Importing the libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

import gc
from humanize import naturalsize
#import lightgbm
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # **Loading the Data**

# %%
DATA_DIR = "/kaggle/input/open-problems-multimodal/"
FP_CELL_METADATA = os.path.join(DATA_DIR,"metadata.csv")

FP_CITE_TRAIN_INPUTS = os.path.join(DATA_DIR,"train_cite_inputs.h5")
FP_CITE_TRAIN_TARGETS = os.path.join(DATA_DIR,"train_cite_targets.h5")
FP_CITE_TEST_INPUTS = os.path.join(DATA_DIR,"test_cite_inputs.h5")
FP_CITE_TEST_INPUTS_FIX = os.path.join(DATA_DIR,"test_cite_inputs_day_2_donor_27678.h5")

FP_MULTIOME_TRAIN_INPUTS = os.path.join(DATA_DIR,"train_multi_inputs.h5")
FP_MULTIOME_TRAIN_TARGETS = os.path.join(DATA_DIR,"train_multi_targets.h5")
FP_MULTIOME_TEST_INPUTS = os.path.join(DATA_DIR,"test_multi_inputs.h5")

FP_SUBMISSION = os.path.join(DATA_DIR,"sample_submission.csv")
FP_EVALUATION_IDS = os.path.join(DATA_DIR,"evaluation_ids.csv")

# %%
# Load list of important columns
important_columns_path = '../input/kagglegenes/important_columns.csv'
df_imp_cols =  pd.read_csv(important_columns_path)

# %%
# %%time

# Load train data. In this case, it is impossible to load only important columns, 
# so I have to load all the data, and then remove columns that are not in important columns list.
df = pd.read_hdf(FP_CITE_TRAIN_INPUTS)
df = df[df_imp_cols['important_columns']]
print('import finished')
gc.collect()
df.shape
# Out:
# import finished
# CPU times: user 23.9 s, sys: 7.62 s, total: 31.5 s
# Wall time: 52.7 s
# (70988, 642)

# %%
# Check dataframe size
size = df.memory_usage(deep='True').sum()
print(naturalsize(size))
# Out:
# 187.2 MB

# %%
# I made it possible to run this notebook with SUBMIT = False in case if I am going to run cross-validation only
SUBMIT = True
CROSS_VALIDATE = False

# %%
# %%time
# Load the test data (this step is skipped if notebook runs only for cross-validation)

if SUBMIT:
    df_test = pd.read_hdf(FP_CITE_TEST_INPUTS)
    df_test = df_test[df_imp_cols['important_columns']]
    print('import of test data finished')
    print(df_test.shape)
# Out:
# import of test data finished
# (48663, 642)
# CPU times: user 16.3 s, sys: 2.47 s, total: 18.7 s
# Wall time: 32.9 s

# %%
# %%time

# Load metadata and select rows that refer to CITE
md_df = pd.read_csv(FP_CELL_METADATA, index_col='cell_id')
md_df = md_df.loc[md_df['technology'] == "citeseq"]
md_df['day'] = md_df['day'].astype('int8')
del md_df['technology']
# Join the metadata to train.
df = df.join(md_df, how = 'left', on = 'cell_id')
# Join the metadata to test.
if SUBMIT:
    df_test = df_test.join(md_df, how = 'left', on = 'cell_id')
    print(df_test.shape)
del md_df
gc.collect()
df.shape
# Out:
# (48663, 645)
# CPU times: user 529 ms, sys: 82 ms, total: 611 ms
# Wall time: 730 ms
# (70988, 645)

# %%
# %%time
# Load the prepared TruncatedSVD data and join it to the rest of train/test datasets.
# There was a mess with organizers initially publishing wrong data as part of test set.
# They've later released a fix (see FP_CITE_TEST_INPUTS_FIX) for information only.
# This means participants didn't have to make predictions for the fixed data, but could use it for their models.
# I used that data to calculate the TruncatedSVD.
# This is why this part of code is not as simple as it could be otherwise.

svd_path = '../input/notebookb136a7c42f/svd.csv'
svd = pd.read_csv(svd_path)
svd = svd.add_prefix('svd_')
svd_train = svd.iloc[:70988]
print(svd_train.shape)

#join the svd data to train
df = df.reset_index()
df = pd.concat([df, svd_train], axis=1)

#join the svd data to test
if SUBMIT:
    df_test = df_test.iloc[7476:]
    df_test = df_test.reset_index()
    svd_test = svd.iloc[70988:112175].reset_index(drop = True)
    print(svd_test.shape)
    df_test = pd.concat([df_test, svd_test], axis=1)
    del svd_test

del svd, svd_train
gc.collect()
print(df.shape)
if SUBMIT:
    print(df_test.shape)
# Out:
# (70988, 512)
# (41187, 512)
# (70988, 1158)
# (41187, 1158)
# CPU times: user 14.2 s, sys: 1.42 s, total: 15.6 s
# Wall time: 27.4 s

# %%
# %%time
# Import the target values and merge them into train dataframe.

Y = pd.read_hdf(FP_CITE_TRAIN_TARGETS)
Y = Y.add_prefix('y_')
print(f"Y shape: {str(Y.shape):14} {Y.size*4/1024/1024/1024:2.3f} GByte")
df = df.join(Y, how = 'left', on = 'cell_id')

del Y
gc.collect()
df.shape
# Out:
# Y shape: (70988, 140)   0.037 GByte
# CPU times: user 419 ms, sys: 123 ms, total: 542 ms
# Wall time: 960 ms
# (70988, 1298)

# %%
'''
# Experimented with some manually crafted features from raw data, but decided not to include them into final submission.
raw_features_path = '../input/values-from-raw/features_from_raw.ftr'
df_raw_features = pd.read_feather(raw_features_path)
df = df.merge(df_raw_features, how = 'left', on = 'cell_id')
del df_raw_features
gc.collect()
print(df.shape)
if SUBMIT:
    test_raw_features_path = '../input/values-from-raw/features_from_raw_test.ftr'
    df_raw_features_test = pd.read_feather(test_raw_features_path)
    df_test = df_test.merge(df_raw_features_test, how = 'left', on = 'cell_id')
    del df_raw_features_test
    gc.collect()
    print(df_test.shape)
'''
# Out:
# "\n# Experimented with some manually crafted features from raw data, but decided not to include them into final submission.\nraw_features_path = '../input/values-from-raw/features_from_raw.ftr'\ndf_raw_features = pd.read_feather(raw_features_path)\ndf = df.merge(df_raw_features, how = 'left', on = 'cell_id')\ndel df_raw_features\ngc.collect()\nprint(df.shape)\nif SUBMIT:\n    test_raw_features_path = '../input/values-from-raw/features_from_raw_test.ftr'\n    df_raw_features_test = pd.read_feather(test_raw_features_path)\n    df_test = df_test.merge(df_raw_features_test, how = 'left', on = 'cell_id')\n    del df_raw_features_test\n    gc.collect()\n    print(df_test.shape)\n"

# %%
# Made experiments with using TruncatedSVD built on raw data, but cross-validation showed it only decreases
# model's performance, even if I only take first 32 components.
'''
svd_raw_path = '../input/svd-from-raw-data/svd_raw.csv'
svd_raw = pd.read_csv(svd_raw_path)
svd_raw = svd_raw.add_prefix('ext_')
svd_train_raw = svd_raw.iloc[:70988, :32]
#svd = pd.DataFrame(svd, dtype='float16')
print(svd_train_raw.shape)

#join the svd data to train
df = pd.concat([df, svd_train_raw], axis=1)

#join the svd data to test
if SUBMIT:
    print(df_test.shape)
    svd_test_raw = svd_raw.iloc[70988:112175, :32].reset_index(drop=True)
    print(svd_test_raw.shape)
    df_test = pd.concat([df_test, svd_test_raw], axis=1)
    del svd_test_raw

del svd_raw, svd_train_raw
gc.collect()
print(df.shape)
if SUBMIT:
    print(df_test.shape)
'''
# Out:
# "\nsvd_raw_path = '../input/svd-from-raw-data/svd_raw.csv'\nsvd_raw = pd.read_csv(svd_raw_path)\nsvd_raw = svd_raw.add_prefix('ext_')\nsvd_train_raw = svd_raw.iloc[:70988, :32]\n#svd = pd.DataFrame(svd, dtype='float16')\nprint(svd_train_raw.shape)\n\n#join the svd data to train\ndf = pd.concat([df, svd_train_raw], axis=1)\n\n#join the svd data to test\nif SUBMIT:\n    print(df_test.shape)\n    svd_test_raw = svd_raw.iloc[70988:112175, :32].reset_index(drop=True)\n    print(svd_test_raw.shape)\n    df_test = pd.concat([df_test, svd_test_raw], axis=1)\n    del svd_test_raw\n\ndel svd_raw, svd_train_raw\ngc.collect()\nprint(df.shape)\nif SUBMIT:\n    print(df_test.shape)\n"

# %% [markdown]
# # **Cross-validation**

# %%
lightgbm_params = {
     'learning_rate': 0.05, 
     'max_depth': 7, 
     'min_child_samples': 100,
     'subsample': 0.6, 
     "seed": 1,
     "device": "gpu",
     "gpu_platform_id": 0,
     "gpu_device_id": 0,
    }

# %%
# Function to calculate the competition's custom metric.

def correlation_score(y_true, y_pred):
    if type(y_true) == pd.DataFrame: y_true = y_true.values
    if type(y_pred) == pd.DataFrame: y_pred = y_pred.values
    corrsum = 0
    for i in range(len(y_true)):
        corrsum += np.corrcoef(y_true[i], y_pred[i])[1, 0]
    return corrsum / len(y_true)

# %%
if CROSS_VALIDATE:
    df['svd_var1'] = 0
    #df['svd_var2'] = 0
    df['svd_var3'] = 0
    df['svd_var4'] = 0
    df['svd_sex'] = 0
    df.loc[df['donor'] == 13176, 'svd_sex'] = 1
    
    x_cols = [col for col in list(df.columns) if (col.startswith('ENSG')) | (col.startswith('svd'))]
    y_cols = [col for col in list(df.columns) if (col.startswith('y_'))]

# %%
# At some point, close to competition end decided to use different catboost parameters depending on target.
cat_params_slow = {
    "random_state": 23,
    "learning_rate" : 0.02,
    "eval_metric" : 'RMSE', 
    "max_depth" : 7,
    "verbose" : 100,
    "n_estimators" : 300,
    "task_type" : 'GPU'
    }
cat_params_middle = {
    "random_state": 23,
    "learning_rate" : 0.03,
    "eval_metric" : 'RMSE', 
    "max_depth" : 7,
    "verbose" : 100,
    "n_estimators" : 400,
    "task_type" : 'GPU'
    }
cat_params_fast = {
    "random_state": 23,
    "learning_rate" : 0.05,
    "eval_metric" : 'RMSE', 
    "max_depth" : 7,
    "verbose" : 100,
    "n_estimators" : 500,
    "task_type" : 'GPU'
    }

# %%
# Define the targets' grouping depending on how well they can be predicted.
df_model_groups = pd.read_csv('../input/model-groups/model_groups.csv')
df_model_groups['mean'] = df_model_groups.mean(axis=1, numeric_only=True)
df_model_groups['group'] = 2
df_model_groups.loc[df_model_groups['mean'] < 0.25, 'group'] = 1
df_model_groups.loc[df_model_groups['mean'] > 0.5 , 'group'] = 3

y_slow = list(df_model_groups.loc[df_model_groups['group'] == 1, 'columns'])
y_fast = list(df_model_groups.loc[df_model_groups['group'] == 3, 'columns'])

# %%
# Used this to run cross-validation only on 5 targets of 140 - for test.
#y_cols = y_cols[:5]

# Function to perform cv split by day or by donor.
# Closer to the end of competition, cross-validated only on days.
# Also added cross-validation with evaluation set to check how well models converge.
def custom_cv_split(option, d_frame, USE_EVAL_SET=False):
    d_frame['svd_var1'] = d_frame['day']
    if option > 20:
        cv_col = 'donor'
    else:
        d_frame.loc[d_frame['donor'] == 31800, 'svd_var3'] = 1
        d_frame.loc[d_frame['donor'] == 32606, 'svd_var4'] = 1
        cv_col = 'day'
    Xc_tr = d_frame.loc[d_frame[cv_col] != option, x_cols]
    Xc_va = d_frame.loc[d_frame[cv_col] == option, x_cols]
    yc_va = d_frame.loc[d_frame[cv_col] == option, y_cols]
    if USE_EVAL_SET:
        Xc_tr_cv = Xc_tr.sample(frac=0.1, random_state=25)
        Xc_tr = Xc_tr.drop(Xc_tr_cv.index)
        yc_tr_cv = d_frame[y_cols].iloc[Xc_tr_cv.index]
        yc_tr = d_frame[y_cols].iloc[Xc_tr.index]
        return Xc_tr, yc_tr, Xc_va, yc_va, Xc_tr_cv, yc_tr_cv
    else:
        yc_tr = d_frame[y_cols].iloc[Xc_tr.index]
        return Xc_tr, yc_tr, Xc_va, yc_va

# %%
# %%time
# Cross-validation with LGBMRegressor or CatboostRegressor in a loop.

if CROSS_VALIDATE:
    df_mse_corr = pd.DataFrame({'columns': y_cols})
    df_importances = pd.DataFrame({'columns':x_cols})
    #cv_options = [2,3,4, 32606, 31800]
    cv_options = [2,3,4]
    score_list = []
    for cv_option in cv_options:
        X_tr, y_tr, X_va, y_va = custom_cv_split(cv_option, df)
        mse_list = []
        corr_list = []
        for i in range(len(y_cols)):
            print(str(cv_option) + '_' + str(i) + '_' + y_cols[i])
            column_name = str(cv_option) + '_' + y_cols[i]
            y_column_name = 'pred_' + y_cols[i]
            #model = lightgbm.LGBMRegressor(**lightgbm_params)
            if y_cols[i] in y_slow:
                model = CatBoostRegressor(**cat_params_slow)
            elif y_cols[i] in y_fast:
                model = CatBoostRegressor(**cat_params_fast)
            else:
                model = CatBoostRegressor(**cat_params_middle)
            model.fit(X_tr, y_tr.iloc[:,i].copy())
            y_va[y_column_name] = model.predict(X_va)
            df_importances[column_name] = model.feature_importances_
            mse_value = mean_squared_error(y_va.iloc[:,i], y_va.iloc[:,i+len(y_cols)], squared=False)
            corr_value = np.corrcoef(y_va.iloc[:,i], y_va.iloc[:,i+len(y_cols)])[1, 0]
            mse_list.append(mse_value)
            corr_list.append(corr_value)
            print(str(mse_value) + '_' + str(corr_value))
        gc.collect()
        
        # Save the metric values for all 140 models
        cv_option_corr = str(cv_option) + '_corr'
        cv_option_mse = str(cv_option) + '_mse'
        df_mse_corr[cv_option_corr] = corr_list
        df_mse_corr[cv_option_mse] = mse_list   

        # Validate the model (mse and correlation over all 140 columns)
        y_preds = ['pred_' + y for y in y_cols]
        mse = mean_squared_error(y_va[y_cols], y_va[y_preds])
        corrscore = correlation_score(y_va[y_cols], y_va[y_preds])         

        print(f"Fold {cv_option}: mse = {mse:.5f}, corr =  {corrscore:.5f}")
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.39 µs

# %%
# Export the cross-validation predictions for a second-level model.
# Wasn't used in final submission.

if CROSS_VALIDATE & SUBMIT:
    for cols in df_cv_pred:
        if col in y_cols:
            del df_cv_pred[col]
    gc.collect()
    df_cv_pred = df_cv_pred.reset_index()
    export_file_results = 'results_cite_cv.ftr'
    df_cv_pred.to_feather(export_file_results)
    del df_cv_pred

# %%
if CROSS_VALIDATE:
    for col in ['svd_var1', 'svd_var2', 'svd_var3', 'svd_var4', 'svd_sex']:
        if col in df.columns:
            del df[col]

gc.collect()
# Out:
# 42

# %%
# Save the feature importance data.

if CROSS_VALIDATE & SUBMIT:
    export_file_importances = 'imps_cite.ftr'
    df_importances.to_feather(export_file_importances)
    del df_importances

gc.collect()
# Out:
# 21

# %% [markdown]
# # **Prediction**

# %%
# Create features from metadata.
# Note: I couldn't use get_dummies function here, as one of days and one of donors only appear in test dataset.

def add_metadata_features(d_frame):
    d_frame['svd_x_donor_13176'] = 0
    d_frame['svd_x_donor_31800'] = 0
    d_frame['svd_x_donor_32606'] = 0
    d_frame.loc[d_frame['donor'] == 13176, 'svd_x_donor_13176'] = 1
    d_frame.loc[d_frame['donor'] == 31800, 'svd_x_donor_31800'] = 1
    d_frame.loc[d_frame['donor'] == 32606, 'svd_x_donor_32606'] = 1
    d_frame['svd_x_day'] = d_frame['day']
    return d_frame

# %%
# Predict. Ran a few time with cross-validation on 10% of data to check if it makes sense to add more
# iterations. 
'''
if SUBMIT:
    df = add_metadata_features(df)
    df_test = add_metadata_features(df_test)
    x_cols = [col for col in list(df.columns) if (col.startswith('ENSG')) | (col.startswith('svd'))]
    y_cols = [col for col in list(df.columns) if (col.startswith('y_'))]
    best_iteration = []
    best_cv_result = []
    #y_cols = y_cols[:5]
    df_cv = df.sample(frac=0.1, random_state=25)
    df= df.drop(df_cv.index)
    X = df[x_cols].values
    Y = df[y_cols].values
    X_cv = df_cv[x_cols].values
    Y_cv = df_cv[y_cols].values
    for i in range(len(y_cols)):
        print('Training_column: ' + str(i))
        #model = lightgbm.LGBMRegressor(n_estimators=n_estimators, **lightgbm_params)
        #model = CatBoostRegressor(n_estimators=n_estimators, **cat_params)
        if y_cols[i] in y_slow:
            model = CatBoostRegressor(**cat_params_slow)
        elif y_cols[i] in y_fast:
            model = CatBoostRegressor(**cat_params_fast)
        else:
            model = CatBoostRegressor(**cat_params_middle)
        model.fit(X, Y[:,i].copy(), eval_set=[(X_cv, Y_cv[:,i].copy())])
        best_iteration.append(model.best_iteration_)
        best_cv_result.append(correlation_value)
        correlation_value = np.corrcoef(model.predict(X_cv),  Y_cv[:,i])[1, 0]
        print(str(correlation_value))
'''
# Out:
# "\nif SUBMIT:\n    df = add_metadata_features(df)\n    df_test = add_metadata_features(df_test)\n    x_cols = [col for col in list(df.columns) if (col.startswith('ENSG')) | (col.startswith('svd'))]\n    y_cols = [col for col in list(df.columns) if (col.startswith('y_'))]\n    best_iteration = []\n    best_cv_result = []\n    #y_cols = y_cols[:5]\n    df_cv = df.sample(frac=0.1, random_state=25)\n    df= df.drop(df_cv.index)\n    X = df[x_cols].values\n    Y = df[y_cols].values\n    X_cv = df_cv[x_cols].values\n    Y_cv = df_cv[y_cols].values\n    for i in range(len(y_cols)):\n        print('Training_column: ' + str(i))\n        #model = lightgbm.LGBMRegressor(n_estimators=n_estimators, **lightgbm_params)\n        #model = CatBoostRegressor(n_estimators=n_estimators, **cat_params)\n        if y_cols[i] in y_slow:\n            model = CatBoostRegressor(**cat_params_slow)\n        elif y_cols[i] in y_fast:\n            model = CatBoostRegressor(**cat_params_fast)\n        else:\n            model = CatBoostRegressor(**cat_params_middle)\n        model.fit(X, Y[:,i].copy(), eval_set=[(X_cv, Y_cv[:,i].copy())])\n        best_iteration.append(model.best_iteration_)\n        best_cv_result.append(correlation_value)\n        correlation_value = np.corrcoef(model.predict(X_cv),  Y_cv[:,i])[1, 0]\n        print(str(correlation_value))\n"

# %%
# Make predictions.
if SUBMIT:
    df = add_metadata_features(df)
    df_test = add_metadata_features(df_test)
    x_cols = [col for col in list(df.columns) if (col.startswith('ENSG')) | (col.startswith('svd'))]
    y_cols = [col for col in list(df.columns) if (col.startswith('y_'))]
    #y_cols = y_cols[:5]
    X = df[x_cols].values
    Y = df[y_cols].values
    Xt = df_test[x_cols].values
    for i in range(len(y_cols)):
        print('Training_column: ' + str(i))
        #model = lightgbm.LGBMRegressor(n_estimators=n_estimators, **lightgbm_params)
        if y_cols[i] in y_slow:
            model = CatBoostRegressor(**cat_params_slow)
        elif y_cols[i] in y_fast:
            model = CatBoostRegressor(**cat_params_fast)
        else:
            model = CatBoostRegressor(**cat_params_middle)
        model.fit(X, Y[:,i].copy())
        col_name = y_cols[i]
        df_test[col_name] = model.predict(Xt)
# Out:
# Training_column: 0
# 0:	learn: 1.3880658	total: 37.9ms	remaining: 15.1s
# 100:	learn: 1.2274369	total: 2.89s	remaining: 8.56s
# 200:	learn: 1.2000120	total: 5.27s	remaining: 5.22s
# 300:	learn: 1.1826643	total: 7.69s	remaining: 2.53s
# 399:	learn: 1.1691044	total: 10.1s	remaining: 0us
# Training_column: 1
# 0:	learn: 0.8930985	total: 28.2ms	remaining: 8.44s
# 100:	learn: 0.8547100	total: 2.59s	remaining: 5.1s
# 200:	learn: 0.8490743	total: 5.46s	remaining: 2.69s
# 299:	learn: 0.8451139	total: 7.99s	remaining: 0us
# Training_column: 2
# 0:	learn: 0.9192535	total: 29.1ms	remaining: 11.6s
# 100:	learn: 0.8435130	total: 2.95s	remaining: 8.74s
# 200:	learn: 0.8361452	total: 5.53s	remaining: 5.47s
# 300:	learn: 0.8302002	total: 8.13s	remaining: 2.67s
# 399:	learn: 0.8246224	total: 10.7s	remaining: 0us
# Training_column: 3
# 0:	learn: 2.4953868	total: 27.9ms	remaining: 13.9s
# 100:	learn: 1.7882656	total: 2.69s	remaining: 10.6s
# 200:	learn: 1.7434499	total: 5.61s	remaining: 8.34s
# 300:	learn: 1.7154959	total: 8.19s	remaining: 5.42s
# 400:	learn: 1.6922450	total: 10.8s	remaining: 2.67s
# 499:	learn: 1.6704558	total: 13.4s	remaining: 0us
# Training_column: 4
# 0:	learn: 1.9989614	total: 29.9ms	remaining: 14.9s
# 100:	learn: 1.2490464	total: 2.74s	remaining: 10.8s
# 200:	learn: 1.2038992	total: 5.33s	remaining: 7.93s
# 300:	learn: 1.1811843	total: 8.95s	remaining: 5.92s
# 400:	learn: 1.1637426	total: 11.5s	remaining: 2.84s
# 499:	learn: 1.1491024	total: 14s	remaining: 0us
# Training_column: 5
# 0:	learn: 3.5345708	total: 28.9ms	remaining: 14.4s
# 100:	learn: 2.5568859	total: 2.71s	remaining: 10.7s
# 200:	learn: 2.4670998	total: 5.29s	remaining: 7.87s
# 300:	learn: 2.4208373	total: 8.19s	remaining: 5.41s
# 400:	learn: 2.3853012	total: 10.7s	remaining: 2.65s
# 499:	learn: 2.3526767	total: 13.3s	remaining: 0us
# Training_column: 6
# 0:	learn: 5.1919720	total: 27.5ms	remaining: 13.7s
# 100:	learn: 2.8738063	total: 2.6s	remaining: 10.3s
# 200:	learn: 2.7402469	total: 5.13s	remaining: 7.62s
# 300:	learn: 2.6674878	total: 7.63s	remaining: 5.04s
# 400:	learn: 2.6092070	total: 10.5s	remaining: 2.6s
# 499:	learn: 2.5593753	total: 13.1s	remaining: 0us
# Training_column: 7
# 0:	learn: 1.0511962	total: 35.9ms	remaining: 14.3s
# 100:	learn: 0.9565328	total: 2.53s	remaining: 7.49s
# 200:	learn: 0.9440935	total: 4.93s	remaining: 4.88s
# 300:	learn: 0.9366246	total: 7.44s	remaining: 2.45s
# 399:	learn: 0.9297992	total: 10.2s	remaining: 0us
# Training_column: 8
# 0:	learn: 0.8539888	total: 27.1ms	remaining: 10.8s
# 100:	learn: 0.7662726	total: 2.7s	remaining: 7.99s
# 200:	learn: 0.7587391	total: 5.67s	remaining: 5.61s
# 300:	learn: 0.7534909	total: 8.28s	remaining: 2.72s
# 399:	learn: 0.7484489	total: 10.9s	remaining: 0us
# Training_column: 9
# 0:	learn: 1.2372475	total: 29.1ms	remaining: 11.6s
# 100:	learn: 1.0511632	total: 2.63s	remaining: 7.78s
# 200:	learn: 1.0346380	total: 5.09s	remaining: 5.04s
# 300:	learn: 1.0250182	total: 8.53s	remaining: 2.81s
# 399:	learn: 1.0168127	total: 11.1s	remaining: 0us
# Training_column: 10
# 0:	learn: 0.8466707	total: 27.7ms	remaining: 8.29s
# 100:	learn: 0.8349249	total: 2.88s	remaining: 5.67s
# 200:	learn: 0.8308837	total: 5.4s	remaining: 2.66s
# 299:	learn: 0.8277737	total: 7.86s	remaining: 0us
# Training_column: 11
# 0:	learn: 1.1547223	total: 27.2ms	remaining: 8.12s
# 100:	learn: 1.1298439	total: 2.5s	remaining: 4.93s
# 200:	learn: 1.1226814	total: 4.96s	remaining: 2.44s
# 299:	learn: 1.1174444	total: 8.11s	remaining: 0us
# Training_column: 12
# 0:	learn: 1.0441886	total: 27.7ms	remaining: 8.29s
# 100:	learn: 0.9987802	total: 2.58s	remaining: 5.08s
# 200:	learn: 0.9893992	total: 5.24s	remaining: 2.58s
# 299:	learn: 0.9831483	total: 7.93s	remaining: 0us
# Training_column: 13
# 0:	learn: 1.1611189	total: 25.5ms	remaining: 10.2s
# 100:	learn: 1.0266231	total: 2.71s	remaining: 8.03s
# 200:	learn: 1.0079705	total: 5.09s	remaining: 5.04s
# 300:	learn: 0.9993504	total: 7.5s	remaining: 2.46s
# 399:	learn: 0.9920209	total: 10.6s	remaining: 0us
# Training_column: 14
# 0:	learn: 4.9136628	total: 30ms	remaining: 15s
# 100:	learn: 3.6351560	total: 2.73s	remaining: 10.8s
# 200:	learn: 3.5380432	total: 5.33s	remaining: 7.93s
# 300:	learn: 3.4773453	total: 8.3s	remaining: 5.49s
# 400:	learn: 3.4277666	total: 11s	remaining: 2.71s
# 499:	learn: 3.3828022	total: 13.6s	remaining: 0us
# Training_column: 15
# 0:	learn: 2.7237763	total: 24.6ms	remaining: 12.3s
# 100:	learn: 2.0790633	total: 2.43s	remaining: 9.6s
# 200:	learn: 2.0162773	total: 5.81s	remaining: 8.64s
# 300:	learn: 1.9723038	total: 8.56s	remaining: 5.66s
# 400:	learn: 1.9378675	total: 11s	remaining: 2.71s
# 499:	learn: 1.9086435	total: 13.4s	remaining: 0us
# Training_column: 16
# 0:	learn: 3.2011770	total: 30.3ms	remaining: 15.1s
# 100:	learn: 2.2956680	total: 2.76s	remaining: 10.9s
# 200:	learn: 2.2089559	total: 5.32s	remaining: 7.92s
# 300:	learn: 2.1622787	total: 7.86s	remaining: 5.2s
# 400:	learn: 2.1261506	total: 10.8s	remaining: 2.67s
# 499:	learn: 2.0949609	total: 13.4s	remaining: 0us
# Training_column: 17
# 0:	learn: 2.6453677	total: 34.3ms	remaining: 17.1s
# 100:	learn: 1.6007034	total: 2.79s	remaining: 11s
# 200:	learn: 1.5338182	total: 5.34s	remaining: 7.95s
# 300:	learn: 1.4980457	total: 7.87s	remaining: 5.21s
# 400:	learn: 1.4694052	total: 10.5s	remaining: 2.6s
# 499:	learn: 1.4451056	total: 13.4s	remaining: 0us
# Training_column: 18
# 0:	learn: 2.7186909	total: 29.2ms	remaining: 14.6s
# 100:	learn: 1.9867413	total: 3.1s	remaining: 12.2s
# 200:	learn: 1.9390152	total: 6.18s	remaining: 9.19s
# 300:	learn: 1.9050547	total: 9.23s	remaining: 6.1s
# 400:	learn: 1.8758345	total: 11.8s	remaining: 2.92s
# 499:	learn: 1.8488439	total: 14.6s	remaining: 0us
# Training_column: 19
# 0:	learn: 2.0237538	total: 27.8ms	remaining: 11.1s
# 100:	learn: 1.9271533	total: 2.67s	remaining: 7.91s
# 200:	learn: 1.9018726	total: 5.31s	remaining: 5.26s
# 300:	learn: 1.8844654	total: 7.72s	remaining: 2.54s
# 399:	learn: 1.8671897	total: 10.1s	remaining: 0us
# Training_column: 20
# 0:	learn: 0.9199203	total: 26.7ms	remaining: 10.7s
# 100:	learn: 0.8402042	total: 2.61s	remaining: 7.73s
# 200:	learn: 0.8281638	total: 5.21s	remaining: 5.16s
# 300:	learn: 0.8208617	total: 8.18s	remaining: 2.69s
# 399:	learn: 0.8145764	total: 10.7s	remaining: 0us
# Training_column: 21
# 0:	learn: 2.1753181	total: 41ms	remaining: 20.4s
# 100:	learn: 1.3728662	total: 2.97s	remaining: 11.7s
# 200:	learn: 1.3264352	total: 5.53s	remaining: 8.22s
# 300:	learn: 1.3023419	total: 8.07s	remaining: 5.33s
# 400:	learn: 1.2834753	total: 10.6s	remaining: 2.61s
# 499:	learn: 1.2670463	total: 13.9s	remaining: 0us
# Training_column: 22
# 0:	learn: 1.0302637	total: 27.2ms	remaining: 8.12s
# 100:	learn: 1.0192286	total: 2.85s	remaining: 5.63s
# 200:	learn: 1.0140641	total: 5.33s	remaining: 2.63s
# 299:	learn: 1.0095744	total: 7.78s	remaining: 0us
# Training_column: 23
# 0:	learn: 1.2310067	total: 28.8ms	remaining: 11.5s
# 100:	learn: 1.1290836	total: 2.61s	remaining: 7.73s
# 200:	learn: 1.1147695	total: 5.14s	remaining: 5.09s
# 300:	learn: 1.1047929	total: 7.66s	remaining: 2.52s
# 399:	learn: 1.0965374	total: 11.1s	remaining: 0us
# Training_column: 24
# 0:	learn: 4.4497661	total: 34.6ms	remaining: 17.2s
# 100:	learn: 3.1424713	total: 2.94s	remaining: 11.6s
# 200:	learn: 3.0488288	total: 5.62s	remaining: 8.36s
# 300:	learn: 2.9975131	total: 8.19s	remaining: 5.42s
# 400:	learn: 2.9549480	total: 10.8s	remaining: 2.66s
# 499:	learn: 2.9154562	total: 13.5s	remaining: 0us
# Training_column: 25
# 0:	learn: 0.9692372	total: 27ms	remaining: 8.08s
# 100:	learn: 0.9349129	total: 2.5s	remaining: 4.92s
# 200:	learn: 0.9281838	total: 5.89s	remaining: 2.9s
# 299:	learn: 0.9245029	total: 8.35s	remaining: 0us
# Training_column: 26
# 0:	learn: 0.9034324	total: 25.7ms	remaining: 7.7s
# 100:	learn: 0.8941394	total: 2.84s	remaining: 5.59s
# 200:	learn: 0.8901664	total: 5.31s	remaining: 2.62s
# 299:	learn: 0.8867797	total: 7.81s	remaining: 0us
# Training_column: 27
# 0:	learn: 0.8953543	total: 27.5ms	remaining: 8.21s
# 100:	learn: 0.8721600	total: 2.5s	remaining: 4.92s
# 200:	learn: 0.8666719	total: 4.9s	remaining: 2.42s
# 299:	learn: 0.8628971	total: 8.16s	remaining: 0us
# Training_column: 28
# 0:	learn: 0.8686476	total: 29.1ms	remaining: 11.6s
# 100:	learn: 0.7693665	total: 2.6s	remaining: 7.69s
# 200:	learn: 0.7617887	total: 5.49s	remaining: 5.44s
# 300:	learn: 0.7562519	total: 8.07s	remaining: 2.65s
# 399:	learn: 0.7511826	total: 10.6s	remaining: 0us
# Training_column: 29
# 0:	learn: 0.7972452	total: 26.6ms	remaining: 10.6s
# 100:	learn: 0.7456164	total: 2.49s	remaining: 7.38s
# 200:	learn: 0.7397071	total: 4.94s	remaining: 4.89s
# 300:	learn: 0.7351491	total: 8.41s	remaining: 2.77s
# 399:	learn: 0.7305246	total: 11.2s	remaining: 0us
# Training_column: 30
# 0:	learn: 0.8340698	total: 27.7ms	remaining: 8.28s
# 100:	learn: 0.7952695	total: 2.97s	remaining: 5.85s
# 200:	learn: 0.7898666	total: 5.57s	remaining: 2.74s
# 299:	learn: 0.7860844	total: 8.14s	remaining: 0us
# Training_column: 31
# 0:	learn: 0.8579145	total: 29.5ms	remaining: 8.82s
# 100:	learn: 0.8184640	total: 2.65s	remaining: 5.23s
# 200:	learn: 0.8129777	total: 5.94s	remaining: 2.93s
# 299:	learn: 0.8092031	total: 8.68s	remaining: 0us
# Training_column: 32
# 0:	learn: 0.7806137	total: 27.5ms	remaining: 8.22s
# 100:	learn: 0.7573224	total: 2.54s	remaining: 5.01s
# 200:	learn: 0.7535788	total: 5.45s	remaining: 2.69s
# 299:	learn: 0.7503295	total: 8.02s	remaining: 0us
# Training_column: 33
# 0:	learn: 0.7848020	total: 26.3ms	remaining: 7.87s
# 100:	learn: 0.7658082	total: 2.87s	remaining: 5.66s
# 200:	learn: 0.7619512	total: 5.49s	remaining: 2.71s
# 299:	learn: 0.7587803	total: 8.81s	remaining: 0us
# Training_column: 34
# 0:	learn: 0.9356923	total: 27.2ms	remaining: 8.13s
# 100:	learn: 0.9181775	total: 2.59s	remaining: 5.1s
# 200:	learn: 0.9135384	total: 5.12s	remaining: 2.52s
# 299:	learn: 0.9098100	total: 7.89s	remaining: 0us
# Training_column: 35
# 0:	learn: 0.8842525	total: 25.1ms	remaining: 7.49s
# 100:	learn: 0.8497915	total: 2.42s	remaining: 4.78s
# 200:	learn: 0.8425180	total: 5.18s	remaining: 2.55s
# 299:	learn: 0.8386518	total: 7.64s	remaining: 0us
# Training_column: 36
# 0:	learn: 1.0429273	total: 37.3ms	remaining: 14.9s
# 100:	learn: 0.9322772	total: 2.76s	remaining: 8.17s
# 200:	learn: 0.9236097	total: 5.4s	remaining: 5.35s
# 300:	learn: 0.9171599	total: 8.01s	remaining: 2.63s
# 399:	learn: 0.9111811	total: 10.8s	remaining: 0us
# Training_column: 37
# 0:	learn: 6.0467690	total: 29.1ms	remaining: 14.5s
# 100:	learn: 4.2006597	total: 2.7s	remaining: 10.7s
# 200:	learn: 4.0676622	total: 5.59s	remaining: 8.32s
# 300:	learn: 3.9947278	total: 8.66s	remaining: 5.72s
# 400:	learn: 3.9385661	total: 11.4s	remaining: 2.81s
# 499:	learn: 3.8866882	total: 14s	remaining: 0us
# Training_column: 38
# 0:	learn: 0.9549333	total: 28.2ms	remaining: 11.3s
# 100:	learn: 0.8574820	total: 2.65s	remaining: 7.84s
# 200:	learn: 0.8500365	total: 5.38s	remaining: 5.33s
# 300:	learn: 0.8443501	total: 8.12s	remaining: 2.67s
# 399:	learn: 0.8389696	total: 10.7s	remaining: 0us
# Training_column: 39
# 0:	learn: 1.2170162	total: 28.6ms	remaining: 8.55s
# 100:	learn: 1.1972137	total: 3.36s	remaining: 6.62s
# 200:	learn: 1.1904827	total: 5.84s	remaining: 2.88s
# 299:	learn: 1.1852733	total: 8.27s	remaining: 0us
# Training_column: 40
# 0:	learn: 0.9436458	total: 27.6ms	remaining: 8.26s
# 100:	learn: 0.9164473	total: 2.46s	remaining: 4.84s
# 200:	learn: 0.9057392	total: 4.82s	remaining: 2.37s
# 299:	learn: 0.8980666	total: 7.55s	remaining: 0us
# Training_column: 41
# 0:	learn: 1.0298502	total: 26.7ms	remaining: 10.7s
# 100:	learn: 0.9783694	total: 2.62s	remaining: 7.77s
# 200:	learn: 0.9709168	total: 6.08s	remaining: 6.02s
# 300:	learn: 0.9651619	total: 8.54s	remaining: 2.81s
# 399:	learn: 0.9590195	total: 11s	remaining: 0us
# Training_column: 42
# 0:	learn: 0.9640819	total: 25.3ms	remaining: 10.1s
# 100:	learn: 0.9031310	total: 2.53s	remaining: 7.5s
# 200:	learn: 0.8957656	total: 5.07s	remaining: 5.02s
# 300:	learn: 0.8902613	total: 7.88s	remaining: 2.59s
# 399:	learn: 0.8848727	total: 10.4s	remaining: 0us
# Training_column: 43
# 0:	learn: 4.8105237	total: 28.7ms	remaining: 14.3s
# 100:	learn: 2.4284607	total: 3.54s	remaining: 14s
# 200:	learn: 2.3165170	total: 6.01s	remaining: 8.94s
# 300:	learn: 2.2493406	total: 8.48s	remaining: 5.61s
# 400:	learn: 2.1958745	total: 11s	remaining: 2.71s
# 499:	learn: 2.1476826	total: 13.8s	remaining: 0us
# Training_column: 44
# 0:	learn: 0.8960224	total: 24.5ms	remaining: 9.78s
# 100:	learn: 0.8462351	total: 2.83s	remaining: 8.37s
# 200:	learn: 0.8386308	total: 5.26s	remaining: 5.21s
# 300:	learn: 0.8333617	total: 7.74s	remaining: 2.55s
# 399:	learn: 0.8287247	total: 10.2s	remaining: 0us
# Training_column: 45
# 0:	learn: 0.8454352	total: 26.7ms	remaining: 7.98s
# 100:	learn: 0.8167942	total: 2.52s	remaining: 4.97s
# 200:	learn: 0.8124156	total: 5.11s	remaining: 2.51s
# 299:	learn: 0.8089030	total: 8.03s	remaining: 0us
# Training_column: 46
# 0:	learn: 1.4141115	total: 29.1ms	remaining: 11.6s
# 100:	learn: 1.2610907	total: 2.73s	remaining: 8.07s
# 200:	learn: 1.2460330	total: 5.38s	remaining: 5.32s
# 300:	learn: 1.2363301	total: 7.86s	remaining: 2.58s
# 399:	learn: 1.2280425	total: 10.3s	remaining: 0us
# Training_column: 47
# 0:	learn: 1.1434921	total: 25.5ms	remaining: 10.2s
# 100:	learn: 1.0438510	total: 2.41s	remaining: 7.14s
# 200:	learn: 1.0265446	total: 4.8s	remaining: 4.75s
# 300:	learn: 1.0165451	total: 7.43s	remaining: 2.44s
# 399:	learn: 1.0084098	total: 9.93s	remaining: 0us
# Training_column: 48
# 0:	learn: 4.8476795	total: 28.4ms	remaining: 14.2s
# 100:	learn: 2.8902682	total: 2.98s	remaining: 11.8s
# 200:	learn: 2.7803384	total: 5.6s	remaining: 8.33s
# 300:	learn: 2.7177661	total: 8.22s	remaining: 5.43s
# 400:	learn: 2.6720487	total: 11.7s	remaining: 2.89s
# 499:	learn: 2.6318210	total: 14.5s	remaining: 0us
# Training_column: 49
# 0:	learn: 0.8460452	total: 28.6ms	remaining: 8.56s
# 100:	learn: 0.8288013	total: 2.91s	remaining: 5.73s
# 200:	learn: 0.8245489	total: 5.55s	remaining: 2.73s
# 299:	learn: 0.8210306	total: 8.09s	remaining: 0us
# Training_column: 50
# 0:	learn: 0.8775568	total: 27ms	remaining: 10.8s
# 100:	learn: 0.7930824	total: 2.75s	remaining: 8.13s
# 200:	learn: 0.7853644	total: 5.79s	remaining: 5.73s
# 300:	learn: 0.7797766	total: 8.69s	remaining: 2.86s
# 399:	learn: 0.7746207	total: 11.6s	remaining: 0us
# Training_column: 51
# 0:	learn: 0.9176258	total: 27.8ms	remaining: 8.3s
# 100:	learn: 0.8795400	total: 2.96s	remaining: 5.83s
# 200:	learn: 0.8730439	total: 5.58s	remaining: 2.75s
# 299:	learn: 0.8685723	total: 8.11s	remaining: 0us
# Training_column: 52
# 0:	learn: 1.9029184	total: 30ms	remaining: 12s
# 100:	learn: 1.5002499	total: 2.77s	remaining: 8.19s
# 200:	learn: 1.4674284	total: 6.12s	remaining: 6.06s
# 300:	learn: 1.4479013	total: 8.71s	remaining: 2.86s
# 399:	learn: 1.4317350	total: 11.6s	remaining: 0us
# Training_column: 53
# 0:	learn: 1.0215740	total: 25.6ms	remaining: 7.66s
# 100:	learn: 0.9871483	total: 2.73s	remaining: 5.38s
# 200:	learn: 0.9750440	total: 5.11s	remaining: 2.52s
# 299:	learn: 0.9693456	total: 7.5s	remaining: 0us
# Training_column: 54
# 0:	learn: 1.3379327	total: 28.2ms	remaining: 11.2s
# 100:	learn: 1.1155789	total: 2.73s	remaining: 8.1s
# 200:	learn: 1.0988225	total: 6.09s	remaining: 6.03s
# 300:	learn: 1.0895501	total: 8.64s	remaining: 2.84s
# 399:	learn: 1.0815958	total: 11.5s	remaining: 0us
# Training_column: 55
# 0:	learn: 1.2037677	total: 30.9ms	remaining: 15.4s
# 100:	learn: 0.9305042	total: 2.84s	remaining: 11.2s
# 200:	learn: 0.9063471	total: 5.57s	remaining: 8.29s
# 300:	learn: 0.8919818	total: 8.1s	remaining: 5.35s
# 400:	learn: 0.8795303	total: 10.6s	remaining: 2.63s
# 499:	learn: 0.8688476	total: 13.2s	remaining: 0us
# Training_column: 56
# 0:	learn: 0.8943767	total: 27.5ms	remaining: 8.23s
# 100:	learn: 0.8550895	total: 2.64s	remaining: 5.2s
# 200:	learn: 0.8493598	total: 5.53s	remaining: 2.72s
# 299:	learn: 0.8453141	total: 8.1s	remaining: 0us
# Training_column: 57
# 0:	learn: 2.6920662	total: 79.2ms	remaining: 39.5s
# 100:	learn: 1.7521613	total: 3.01s	remaining: 11.9s
# 200:	learn: 1.6826622	total: 5.63s	remaining: 8.38s
# 300:	learn: 1.6451771	total: 8.22s	remaining: 5.44s
# 400:	learn: 1.6159550	total: 10.9s	remaining: 2.69s
# 499:	learn: 1.5906895	total: 14.5s	remaining: 0us
# Training_column: 58
# 0:	learn: 1.1919272	total: 26.3ms	remaining: 10.5s
# 100:	learn: 1.0423818	total: 2.67s	remaining: 7.91s
# 200:	learn: 1.0129086	total: 5.02s	remaining: 4.97s
# 300:	learn: 1.0023728	total: 7.4s	remaining: 2.43s
# 399:	learn: 0.9957536	total: 9.79s	remaining: 0us
# Training_column: 59
# 0:	learn: 1.0481771	total: 24.5ms	remaining: 7.31s
# 100:	learn: 1.0228784	total: 2.44s	remaining: 4.8s
# 200:	learn: 1.0166304	total: 4.9s	remaining: 2.41s
# 299:	learn: 1.0123276	total: 8.3s	remaining: 0us
# Training_column: 60
# 0:	learn: 1.1580563	total: 25.1ms	remaining: 10s
# 100:	learn: 1.0252601	total: 2.62s	remaining: 7.75s
# 200:	learn: 1.0123019	total: 5.29s	remaining: 5.23s
# 300:	learn: 1.0042454	total: 7.79s	remaining: 2.56s
# 399:	learn: 0.9973054	total: 10.3s	remaining: 0us
# Training_column: 61
# 0:	learn: 0.8295972	total: 28.2ms	remaining: 11.3s
# 100:	learn: 0.7046121	total: 2.6s	remaining: 7.7s
# 200:	learn: 0.6941744	total: 5.15s	remaining: 5.1s
# 300:	learn: 0.6887895	total: 8.62s	remaining: 2.84s
# 399:	learn: 0.6842560	total: 11.1s	remaining: 0us
# Training_column: 62
# 0:	learn: 0.9142149	total: 27.5ms	remaining: 11s
# 100:	learn: 0.8147900	total: 2.96s	remaining: 8.75s
# 200:	learn: 0.8069458	total: 5.56s	remaining: 5.5s
# 300:	learn: 0.8014374	total: 8.14s	remaining: 2.68s
# 399:	learn: 0.7961534	total: 10.7s	remaining: 0us
# Training_column: 63
# 0:	learn: 0.8413425	total: 27.9ms	remaining: 11.1s
# 100:	learn: 0.7873188	total: 2.71s	remaining: 8.04s
# 200:	learn: 0.7812224	total: 6.42s	remaining: 6.36s
# 300:	learn: 0.7761221	total: 9s	remaining: 2.96s
# 399:	learn: 0.7710962	total: 11.5s	remaining: 0us
# Training_column: 64
# 0:	learn: 1.3725989	total: 27.1ms	remaining: 10.8s
# 100:	learn: 1.1477973	total: 2.44s	remaining: 7.22s
# 200:	learn: 1.1148523	total: 4.82s	remaining: 4.77s
# 300:	learn: 1.0945642	total: 7.22s	remaining: 2.38s
# 399:	learn: 1.0776106	total: 10s	remaining: 0us
# Training_column: 65
# 0:	learn: 1.1198455	total: 26.1ms	remaining: 10.4s
# 100:	learn: 1.0264278	total: 3.45s	remaining: 10.2s
# 200:	learn: 1.0147502	total: 5.94s	remaining: 5.88s
# 300:	learn: 1.0077436	total: 8.38s	remaining: 2.75s
# 399:	learn: 1.0017021	total: 10.8s	remaining: 0us
# Training_column: 66
# 0:	learn: 1.4233721	total: 28.2ms	remaining: 14.1s
# 100:	learn: 1.2042124	total: 2.61s	remaining: 10.3s
# 200:	learn: 1.1887862	total: 5.12s	remaining: 7.61s
# 300:	learn: 1.1750467	total: 7.82s	remaining: 5.17s
# 400:	learn: 1.1612462	total: 10.5s	remaining: 2.59s
# 499:	learn: 1.1475886	total: 13.1s	remaining: 0us
# Training_column: 67
# 0:	learn: 1.0520048	total: 30.7ms	remaining: 12.2s
# 100:	learn: 0.9602206	total: 2.76s	remaining: 8.16s
# 200:	learn: 0.9502657	total: 5.45s	remaining: 5.39s
# 300:	learn: 0.9430103	total: 8.11s	remaining: 2.67s
# 399:	learn: 0.9364388	total: 11.1s	remaining: 0us
# Training_column: 68
# 0:	learn: 1.5847888	total: 28.1ms	remaining: 14s
# 100:	learn: 1.1658123	total: 2.89s	remaining: 11.4s
# 200:	learn: 1.1433738	total: 5.5s	remaining: 8.18s
# 300:	learn: 1.1290168	total: 8.04s	remaining: 5.32s
# 400:	learn: 1.1160038	total: 11.3s	remaining: 2.79s
# 499:	learn: 1.1037909	total: 14.2s	remaining: 0us
# Training_column: 69
# 0:	learn: 1.1417653	total: 25.2ms	remaining: 10s
# 100:	learn: 0.9742742	total: 2.44s	remaining: 7.23s
# 200:	learn: 0.9505845	total: 5.12s	remaining: 5.07s
# 300:	learn: 0.9384775	total: 7.53s	remaining: 2.48s
# 399:	learn: 0.9286662	total: 9.93s	remaining: 0us
# Training_column: 70
# 0:	learn: 0.7263595	total: 29.1ms	remaining: 11.6s
# 100:	learn: 0.6756538	total: 2.68s	remaining: 7.93s
# 200:	learn: 0.6696967	total: 5.92s	remaining: 5.86s
# 300:	learn: 0.6653235	total: 8.43s	remaining: 2.77s
# 399:	learn: 0.6611908	total: 11.3s	remaining: 0us
# Training_column: 71
# 0:	learn: 0.7347408	total: 27.1ms	remaining: 10.8s
# 100:	learn: 0.6890281	total: 2.84s	remaining: 8.41s
# 200:	learn: 0.6831334	total: 5.27s	remaining: 5.22s
# 300:	learn: 0.6788551	total: 7.77s	remaining: 2.56s
# 399:	learn: 0.6749995	total: 10.2s	remaining: 0us
# Training_column: 72
# 0:	learn: 1.0676159	total: 42.5ms	remaining: 12.7s
# 100:	learn: 1.0328506	total: 2.68s	remaining: 5.28s
# 200:	learn: 1.0247316	total: 5.12s	remaining: 2.52s
# 299:	learn: 1.0203621	total: 7.79s	remaining: 0us
# Training_column: 73
# 0:	learn: 5.4300570	total: 32.6ms	remaining: 16.3s
# 100:	learn: 3.4099853	total: 2.84s	remaining: 11.2s
# 200:	learn: 3.2514502	total: 5.61s	remaining: 8.35s
# 300:	learn: 3.1731988	total: 8.24s	remaining: 5.45s
# 400:	learn: 3.1171159	total: 10.8s	remaining: 2.67s
# 499:	learn: 3.0701965	total: 13.4s	remaining: 0us
# Training_column: 74
# 0:	learn: 0.8498352	total: 27.2ms	remaining: 8.13s
# 100:	learn: 0.8231473	total: 2.61s	remaining: 5.14s
# 200:	learn: 0.8177956	total: 5.53s	remaining: 2.73s
# 299:	learn: 0.8141468	total: 8.04s	remaining: 0us
# Training_column: 75
# 0:	learn: 4.2338464	total: 29.2ms	remaining: 14.6s
# 100:	learn: 2.7953603	total: 3.07s	remaining: 12.1s
# 200:	learn: 2.6764930	total: 5.79s	remaining: 8.61s
# 300:	learn: 2.6154487	total: 8.44s	remaining: 5.58s
# 400:	learn: 2.5719602	total: 11s	remaining: 2.73s
# 499:	learn: 2.5339033	total: 14.5s	remaining: 0us
# Training_column: 76
# 0:	learn: 0.9879537	total: 28.2ms	remaining: 8.43s
# 100:	learn: 0.9607310	total: 3.05s	remaining: 6s
# 200:	learn: 0.9551652	total: 5.63s	remaining: 2.77s
# 299:	learn: 0.9510111	total: 8.18s	remaining: 0us
# Training_column: 77
# 0:	learn: 2.3184422	total: 27.6ms	remaining: 11s
# 100:	learn: 1.9926929	total: 2.63s	remaining: 7.77s
# 200:	learn: 1.9352339	total: 5.23s	remaining: 5.18s
# 300:	learn: 1.9034643	total: 7.81s	remaining: 2.57s
# 399:	learn: 1.8802632	total: 11.3s	remaining: 0us
# Training_column: 78
# 0:	learn: 1.0891073	total: 26.2ms	remaining: 7.83s
# 100:	learn: 1.0533448	total: 2.74s	remaining: 5.4s
# 200:	learn: 1.0446749	total: 5.15s	remaining: 2.53s
# 299:	learn: 1.0403913	total: 7.52s	remaining: 0us
# Training_column: 79
# 0:	learn: 1.0965266	total: 27.8ms	remaining: 11.1s
# 100:	learn: 0.9762170	total: 2.52s	remaining: 7.47s
# 200:	learn: 0.9644809	total: 5s	remaining: 4.95s
# 300:	learn: 0.9578474	total: 7.49s	remaining: 2.46s
# 399:	learn: 0.9515712	total: 11.1s	remaining: 0us
# Training_column: 80
# 0:	learn: 3.1229921	total: 27.3ms	remaining: 13.6s
# 100:	learn: 2.3485604	total: 2.94s	remaining: 11.6s
# 200:	learn: 2.2748205	total: 5.45s	remaining: 8.1s
# 300:	learn: 2.2285818	total: 7.93s	remaining: 5.24s
# 400:	learn: 2.1914302	total: 10.4s	remaining: 2.57s
# 499:	learn: 2.1593244	total: 13s	remaining: 0us
# Training_column: 81
# 0:	learn: 1.0996198	total: 26.6ms	remaining: 10.6s
# 100:	learn: 0.9545826	total: 2.52s	remaining: 7.47s
# 200:	learn: 0.9332261	total: 5.81s	remaining: 5.75s
# 300:	learn: 0.9188379	total: 8.21s	remaining: 2.7s
# 399:	learn: 0.9080852	total: 10.6s	remaining: 0us
# Training_column: 82
# 0:	learn: 0.9741441	total: 29.8ms	remaining: 11.9s
# 100:	learn: 0.8481877	total: 2.69s	remaining: 7.98s
# 200:	learn: 0.8386755	total: 5.25s	remaining: 5.2s
# 300:	learn: 0.8322932	total: 7.82s	remaining: 2.57s
# 399:	learn: 0.8267621	total: 10.6s	remaining: 0us
# Training_column: 83
# 0:	learn: 0.9635481	total: 35.6ms	remaining: 14.2s
# 100:	learn: 0.9105917	total: 3.38s	remaining: 10s
# 200:	learn: 0.9036246	total: 5.94s	remaining: 5.88s
# 300:	learn: 0.8977149	total: 8.57s	remaining: 2.82s
# 399:	learn: 0.8920614	total: 11.1s	remaining: 0us
# Training_column: 84
# 0:	learn: 0.8049414	total: 28.8ms	remaining: 8.62s
# 100:	learn: 0.7890437	total: 2.64s	remaining: 5.2s
# 200:	learn: 0.7849070	total: 5.19s	remaining: 2.56s
# 299:	learn: 0.7816832	total: 8.02s	remaining: 0us
# Training_column: 85
# 0:	learn: 0.7911618	total: 30.1ms	remaining: 9.01s
# 100:	learn: 0.7709033	total: 2.99s	remaining: 5.9s
# 200:	learn: 0.7662212	total: 5.57s	remaining: 2.74s
# 299:	learn: 0.7627155	total: 8.1s	remaining: 0us
# Training_column: 86
# 0:	learn: 0.8890813	total: 27.3ms	remaining: 10.9s
# 100:	learn: 0.8184975	total: 2.58s	remaining: 7.65s
# 200:	learn: 0.8115908	total: 5.12s	remaining: 5.07s
# 300:	learn: 0.8059102	total: 7.71s	remaining: 2.53s
# 399:	learn: 0.8004489	total: 10.6s	remaining: 0us
# Training_column: 87
# 0:	learn: 0.8705162	total: 26.9ms	remaining: 8.04s
# 100:	learn: 0.8523912	total: 2.84s	remaining: 5.59s
# 200:	learn: 0.8485398	total: 5.5s	remaining: 2.71s
# 299:	learn: 0.8452628	total: 8.02s	remaining: 0us
# Training_column: 88
# 0:	learn: 1.7154906	total: 27.9ms	remaining: 13.9s
# 100:	learn: 1.1573896	total: 2.56s	remaining: 10.1s
# 200:	learn: 1.1317935	total: 5.08s	remaining: 7.55s
# 300:	learn: 1.1140782	total: 7.57s	remaining: 5s
# 400:	learn: 1.0987780	total: 10.4s	remaining: 2.58s
# 499:	learn: 1.0849633	total: 12.9s	remaining: 0us
# Training_column: 89
# 0:	learn: 5.1750031	total: 27.7ms	remaining: 13.8s
# 100:	learn: 2.1373090	total: 2.86s	remaining: 11.3s
# 200:	learn: 2.0336736	total: 5.36s	remaining: 7.98s
# 300:	learn: 1.9689539	total: 7.81s	remaining: 5.16s
# 400:	learn: 1.9178060	total: 10.3s	remaining: 2.54s
# 499:	learn: 1.8737615	total: 13.1s	remaining: 0us
# Training_column: 90
# 0:	learn: 1.0429808	total: 28.7ms	remaining: 11.4s
# 100:	learn: 0.9097439	total: 2.88s	remaining: 8.54s
# 200:	learn: 0.9002857	total: 5.63s	remaining: 5.58s
# 300:	learn: 0.8939929	total: 8.99s	remaining: 2.96s
# 399:	learn: 0.8880462	total: 11.5s	remaining: 0us
# Training_column: 91
# 0:	learn: 0.7804915	total: 29.5ms	remaining: 8.83s
# 100:	learn: 0.7505141	total: 2.62s	remaining: 5.16s
# 200:	learn: 0.7461396	total: 5.17s	remaining: 2.54s
# 299:	learn: 0.7429241	total: 8.07s	remaining: 0us
# Training_column: 92
# 0:	learn: 0.7538804	total: 27.8ms	remaining: 11.1s
# 100:	learn: 0.6816131	total: 2.79s	remaining: 8.27s
# 200:	learn: 0.6752280	total: 6.09s	remaining: 6.03s
# 300:	learn: 0.6707192	total: 8.85s	remaining: 2.91s
# 399:	learn: 0.6664979	total: 11.4s	remaining: 0us
# Training_column: 93
# 0:	learn: 0.9857803	total: 27.7ms	remaining: 11.1s
# 100:	learn: 0.8808025	total: 2.7s	remaining: 7.98s
# 200:	learn: 0.8722437	total: 5.31s	remaining: 5.25s
# 300:	learn: 0.8660306	total: 8.23s	remaining: 2.71s
# 399:	learn: 0.8602671	total: 10.8s	remaining: 0us
# Training_column: 94
# 0:	learn: 2.2290307	total: 38.5ms	remaining: 19.2s
# 100:	learn: 1.3985857	total: 3.63s	remaining: 14.3s
# 200:	learn: 1.3594936	total: 6.29s	remaining: 9.35s
# 300:	learn: 1.3343962	total: 8.86s	remaining: 5.86s
# 400:	learn: 1.3139757	total: 11.8s	remaining: 2.91s
# 499:	learn: 1.2960484	total: 14.3s	remaining: 0us
# Training_column: 95
# 0:	learn: 1.7783108	total: 25.4ms	remaining: 7.59s
# 100:	learn: 1.6949992	total: 2.73s	remaining: 5.39s
# 200:	learn: 1.6646420	total: 5.12s	remaining: 2.52s
# 299:	learn: 1.6464229	total: 7.48s	remaining: 0us
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# Training_column: 96
# 0:	learn: 1.0488591	total: 26.2ms	remaining: 10.5s
# 100:	learn: 0.9616378	total: 2.5s	remaining: 7.4s
# 200:	learn: 0.9527839	total: 4.93s	remaining: 4.88s
# 300:	learn: 0.9465803	total: 7.47s	remaining: 2.46s
# 399:	learn: 0.9406954	total: 10.1s	remaining: 0us
# Training_column: 97
# 0:	learn: 2.6639259	total: 30.5ms	remaining: 15.2s
# 100:	learn: 1.7158407	total: 2.99s	remaining: 11.8s
# 200:	learn: 1.6561376	total: 5.58s	remaining: 8.3s
# 300:	learn: 1.6281572	total: 8.11s	remaining: 5.36s
# 400:	learn: 1.6067617	total: 10.6s	remaining: 2.61s
# 499:	learn: 1.5870562	total: 14s	remaining: 0us
# Training_column: 98
# 0:	learn: 0.8464169	total: 27.4ms	remaining: 8.19s
# 100:	learn: 0.8191111	total: 2.6s	remaining: 5.12s
# 200:	learn: 0.8143471	total: 5.58s	remaining: 2.75s
# 299:	learn: 0.8106361	total: 8.16s	remaining: 0us
# Training_column: 99
# 0:	learn: 4.0724575	total: 35.7ms	remaining: 17.8s
# 100:	learn: 2.4278199	total: 2.75s	remaining: 10.9s
# 200:	learn: 2.3398703	total: 5.36s	remaining: 7.97s
# 300:	learn: 2.2901525	total: 7.92s	remaining: 5.24s
# 400:	learn: 2.2518166	total: 11.6s	remaining: 2.87s
# 499:	learn: 2.2192978	total: 14.2s	remaining: 0us
# Training_column: 100
# 0:	learn: 2.1825563	total: 30.5ms	remaining: 15.2s
# 100:	learn: 1.4748152	total: 3.04s	remaining: 12s
# 200:	learn: 1.4248946	total: 5.63s	remaining: 8.38s
# 300:	learn: 1.3943877	total: 8.24s	remaining: 5.45s
# 400:	learn: 1.3708605	total: 10.9s	remaining: 2.68s
# 499:	learn: 1.3519044	total: 13.6s	remaining: 0us
# Training_column: 101
# 0:	learn: 1.0922172	total: 60.6ms	remaining: 18.1s
# 100:	learn: 1.0469247	total: 2.84s	remaining: 5.6s
# 200:	learn: 1.0334147	total: 5.31s	remaining: 2.62s
# 299:	learn: 1.0268339	total: 7.68s	remaining: 0us
# Training_column: 102
# 0:	learn: 3.5480410	total: 29ms	remaining: 14.5s
# 100:	learn: 2.9637260	total: 2.62s	remaining: 10.4s
# 200:	learn: 2.8976309	total: 5.18s	remaining: 7.71s
# 300:	learn: 2.8517071	total: 7.72s	remaining: 5.1s
# 400:	learn: 2.8125348	total: 10.6s	remaining: 2.62s
# 499:	learn: 2.7763226	total: 13.2s	remaining: 0us
# Training_column: 103
# 0:	learn: 1.0681383	total: 30.6ms	remaining: 12.2s
# 100:	learn: 0.9820457	total: 2.71s	remaining: 8.03s
# 200:	learn: 0.9731327	total: 5.31s	remaining: 5.26s
# 300:	learn: 0.9666261	total: 7.86s	remaining: 2.59s
# 399:	learn: 0.9600808	total: 10.6s	remaining: 0us
# Training_column: 104
# 0:	learn: 2.9145794	total: 28.5ms	remaining: 14.2s
# 100:	learn: 1.9357613	total: 2.67s	remaining: 10.6s
# 200:	learn: 1.8665796	total: 5.55s	remaining: 8.26s
# 300:	learn: 1.8229536	total: 8.16s	remaining: 5.39s
# 400:	learn: 1.7888760	total: 11.4s	remaining: 2.8s
# 499:	learn: 1.7577161	total: 13.9s	remaining: 0us
# Training_column: 105
# 0:	learn: 1.0869964	total: 27.2ms	remaining: 10.9s
# 100:	learn: 1.0280321	total: 2.53s	remaining: 7.48s
# 200:	learn: 1.0198517	total: 5.13s	remaining: 5.08s
# 300:	learn: 1.0133282	total: 7.88s	remaining: 2.59s
# 399:	learn: 1.0072076	total: 10.4s	remaining: 0us
# Training_column: 106
# 0:	learn: 3.3120536	total: 29ms	remaining: 14.5s
# 100:	learn: 2.2371329	total: 2.62s	remaining: 10.3s
# 200:	learn: 2.1746295	total: 5.91s	remaining: 8.79s
# 300:	learn: 2.1365766	total: 8.44s	remaining: 5.58s
# 400:	learn: 2.1066479	total: 11.3s	remaining: 2.8s
# 499:	learn: 2.0795646	total: 13.9s	remaining: 0us
# Training_column: 107
# 0:	learn: 1.5288544	total: 25.5ms	remaining: 10.2s
# 100:	learn: 1.3899523	total: 2.75s	remaining: 8.16s
# 200:	learn: 1.3671985	total: 5.15s	remaining: 5.1s
# 300:	learn: 1.3535422	total: 7.6s	remaining: 2.5s
# 399:	learn: 1.3419491	total: 10s	remaining: 0us
# Training_column: 108
# 0:	learn: 3.7011304	total: 28.9ms	remaining: 14.4s
# 100:	learn: 1.8761226	total: 2.69s	remaining: 10.6s
# 200:	learn: 1.8015200	total: 5.59s	remaining: 8.32s
# 300:	learn: 1.7612727	total: 8.03s	remaining: 5.31s
# 400:	learn: 1.7305897	total: 10.5s	remaining: 2.58s
# 499:	learn: 1.7065179	total: 12.9s	remaining: 0us
# Training_column: 109
# 0:	learn: 2.0949569	total: 28.6ms	remaining: 14.3s
# 100:	learn: 1.6100949	total: 2.56s	remaining: 10.1s
# 200:	learn: 1.5705256	total: 5.01s	remaining: 7.45s
# 300:	learn: 1.5432348	total: 7.73s	remaining: 5.11s
# 400:	learn: 1.5198734	total: 10.7s	remaining: 2.65s
# 499:	learn: 1.4982787	total: 13.4s	remaining: 0us
# Training_column: 110
# 0:	learn: 1.6318410	total: 26.6ms	remaining: 13.3s
# 100:	learn: 1.1343147	total: 2.6s	remaining: 10.3s
# 200:	learn: 1.1129642	total: 5.07s	remaining: 7.54s
# 300:	learn: 1.0975369	total: 7.55s	remaining: 5s
# 400:	learn: 1.0840380	total: 10.4s	remaining: 2.57s
# 499:	learn: 1.0718238	total: 12.9s	remaining: 0us
# Training_column: 111
# 0:	learn: 2.2903533	total: 28.1ms	remaining: 14s
# 100:	learn: 1.6079120	total: 3.78s	remaining: 14.9s
# 200:	learn: 1.5607569	total: 6.36s	remaining: 9.46s
# 300:	learn: 1.5315960	total: 8.95s	remaining: 5.92s
# 400:	learn: 1.5068580	total: 11.6s	remaining: 2.87s
# 499:	learn: 1.4863297	total: 14.3s	remaining: 0us
# Training_column: 112
# 0:	learn: 1.2451573	total: 26.5ms	remaining: 13.2s
# 100:	learn: 0.9476787	total: 2.8s	remaining: 11.1s
# 200:	learn: 0.9322356	total: 5.26s	remaining: 7.83s
# 300:	learn: 0.9212843	total: 7.75s	remaining: 5.13s
# 400:	learn: 0.9111557	total: 10.3s	remaining: 2.54s
# 499:	learn: 0.9012538	total: 13.5s	remaining: 0us
# Training_column: 113
# 0:	learn: 7.6205376	total: 38.1ms	remaining: 19s
# 100:	learn: 4.0151850	total: 2.59s	remaining: 10.2s
# 200:	learn: 3.8400966	total: 5.36s	remaining: 7.98s
# 300:	learn: 3.7101149	total: 7.81s	remaining: 5.16s
# 400:	learn: 3.5917505	total: 10.3s	remaining: 2.55s
# 499:	learn: 3.4896998	total: 12.8s	remaining: 0us
# Training_column: 114
# 0:	learn: 1.0596154	total: 26ms	remaining: 10.4s
# 100:	learn: 0.9847998	total: 2.46s	remaining: 7.28s
# 200:	learn: 0.9743490	total: 5.35s	remaining: 5.3s
# 300:	learn: 0.9681594	total: 8.41s	remaining: 2.77s
# 399:	learn: 0.9619982	total: 10.9s	remaining: 0us
# Training_column: 115
# 0:	learn: 3.1533252	total: 29.8ms	remaining: 14.9s
# 100:	learn: 2.6592466	total: 2.56s	remaining: 10.1s
# 200:	learn: 2.5997910	total: 5.05s	remaining: 7.51s
# 300:	learn: 2.5603842	total: 7.5s	remaining: 4.96s
# 400:	learn: 2.5254043	total: 10.2s	remaining: 2.52s
# 499:	learn: 2.4906602	total: 12.8s	remaining: 0us
# Training_column: 116
# 0:	learn: 2.0002752	total: 27.4ms	remaining: 13.7s
# 100:	learn: 1.5219969	total: 2.96s	remaining: 11.7s
# 200:	learn: 1.4887847	total: 5.42s	remaining: 8.06s
# 300:	learn: 1.4656694	total: 7.91s	remaining: 5.23s
# 400:	learn: 1.4452526	total: 10.4s	remaining: 2.57s
# 499:	learn: 1.4272096	total: 13.3s	remaining: 0us
# Training_column: 117
# 0:	learn: 1.0441556	total: 27.6ms	remaining: 11s
# 100:	learn: 0.9893507	total: 2.59s	remaining: 7.67s
# 200:	learn: 0.9803211	total: 5.48s	remaining: 5.42s
# 300:	learn: 0.9733640	total: 8.05s	remaining: 2.65s
# 399:	learn: 0.9670608	total: 10.8s	remaining: 0us
# Training_column: 118
# 0:	learn: 1.2532105	total: 28.6ms	remaining: 11.4s
# 100:	learn: 1.1705380	total: 2.6s	remaining: 7.68s
# 200:	learn: 1.1552282	total: 5.06s	remaining: 5.01s
# 300:	learn: 1.1455970	total: 7.88s	remaining: 2.59s
# 399:	learn: 1.1373108	total: 10.3s	remaining: 0us
# Training_column: 119
# 0:	learn: 3.6561627	total: 29.6ms	remaining: 14.7s
# 100:	learn: 2.5913701	total: 3.02s	remaining: 11.9s
# 200:	learn: 2.5048438	total: 5.58s	remaining: 8.3s
# 300:	learn: 2.4574110	total: 8.87s	remaining: 5.87s
# 400:	learn: 2.4227109	total: 11.4s	remaining: 2.82s
# 499:	learn: 2.3912895	total: 14.3s	remaining: 0us
# Training_column: 120
# 0:	learn: 0.9589395	total: 26.6ms	remaining: 7.96s
# 100:	learn: 0.9190537	total: 2.77s	remaining: 5.46s
# 200:	learn: 0.9126187	total: 5.19s	remaining: 2.56s
# 299:	learn: 0.9087709	total: 7.66s	remaining: 0us
# Training_column: 121
# 0:	learn: 4.5677775	total: 28.8ms	remaining: 14.4s
# 100:	learn: 3.1453229	total: 2.61s	remaining: 10.3s
# 200:	learn: 3.0593242	total: 5.84s	remaining: 8.68s
# 300:	learn: 2.9994840	total: 8.37s	remaining: 5.53s
# 400:	learn: 2.9491239	total: 11.3s	remaining: 2.78s
# 499:	learn: 2.9049004	total: 13.8s	remaining: 0us
# Training_column: 122
# 0:	learn: 0.9778287	total: 35.8ms	remaining: 10.7s
# 100:	learn: 0.9637852	total: 2.63s	remaining: 5.19s
# 200:	learn: 0.9591687	total: 5.18s	remaining: 2.55s
# 299:	learn: 0.9550480	total: 7.7s	remaining: 0us
# Training_column: 123
# 0:	learn: 1.0662182	total: 56.7ms	remaining: 17s
# 100:	learn: 1.0541429	total: 3.34s	remaining: 6.58s
# 200:	learn: 1.0494342	total: 5.9s	remaining: 2.9s
# 299:	learn: 1.0450730	total: 8.76s	remaining: 0us
# Training_column: 124
# 0:	learn: 1.0098004	total: 30.7ms	remaining: 12.3s
# 100:	learn: 0.9385827	total: 2.95s	remaining: 8.73s
# 200:	learn: 0.9307654	total: 5.64s	remaining: 5.58s
# 300:	learn: 0.9246816	total: 8.22s	remaining: 2.7s
# 399:	learn: 0.9184776	total: 10.8s	remaining: 0us
# Training_column: 125
# 0:	learn: 0.9888188	total: 28ms	remaining: 11.2s
# 100:	learn: 0.9268954	total: 2.67s	remaining: 7.92s
# 200:	learn: 0.9190063	total: 5.29s	remaining: 5.24s
# 300:	learn: 0.9127711	total: 8.22s	remaining: 2.7s
# 399:	learn: 0.9065335	total: 10.8s	remaining: 0us
# Training_column: 126
# 0:	learn: 0.8975341	total: 28.9ms	remaining: 8.65s
# 100:	learn: 0.8787332	total: 2.69s	remaining: 5.29s
# 200:	learn: 0.8744136	total: 5.33s	remaining: 2.63s
# 299:	learn: 0.8706003	total: 7.9s	remaining: 0us
# Training_column: 127
# 0:	learn: 1.2313813	total: 28.3ms	remaining: 14.1s
# 100:	learn: 0.9888617	total: 2.64s	remaining: 10.4s
# 200:	learn: 0.9662883	total: 5.2s	remaining: 7.73s
# 300:	learn: 0.9503245	total: 8.09s	remaining: 5.35s
# 400:	learn: 0.9369873	total: 10.6s	remaining: 2.63s
# 499:	learn: 0.9246594	total: 13.2s	remaining: 0us
# Training_column: 128
# 0:	learn: 0.8944703	total: 26.4ms	remaining: 7.91s
# 100:	learn: 0.8646491	total: 2.46s	remaining: 4.84s
# 200:	learn: 0.8601903	total: 4.95s	remaining: 2.44s
# 299:	learn: 0.8566961	total: 7.46s	remaining: 0us
# Training_column: 129
# 0:	learn: 0.9523624	total: 25.5ms	remaining: 10.2s
# 100:	learn: 0.8967905	total: 2.44s	remaining: 7.23s
# 200:	learn: 0.8878906	total: 5.28s	remaining: 5.23s
# 300:	learn: 0.8816978	total: 7.79s	remaining: 2.56s
# 399:	learn: 0.8760538	total: 10.3s	remaining: 0us
# Training_column: 130
# 0:	learn: 0.8342364	total: 29.2ms	remaining: 8.74s
# 100:	learn: 0.8094468	total: 2.63s	remaining: 5.19s
# 200:	learn: 0.8043268	total: 5.25s	remaining: 2.59s
# 299:	learn: 0.8004779	total: 7.82s	remaining: 0us
# Training_column: 131
# 0:	learn: 3.1416527	total: 29.4ms	remaining: 14.7s
# 100:	learn: 2.4206631	total: 2.7s	remaining: 10.7s
# 200:	learn: 2.3491943	total: 5.73s	remaining: 8.52s
# 300:	learn: 2.3077081	total: 8.36s	remaining: 5.53s
# 400:	learn: 2.2723641	total: 11s	remaining: 2.72s
# 499:	learn: 2.2424668	total: 13.6s	remaining: 0us
# Training_column: 132
# 0:	learn: 1.1295782	total: 28.7ms	remaining: 11.5s
# 100:	learn: 1.0030874	total: 2.69s	remaining: 7.97s
# 200:	learn: 0.9925777	total: 5.91s	remaining: 5.85s
# 300:	learn: 0.9853810	total: 8.79s	remaining: 2.89s
# 399:	learn: 0.9785577	total: 11.3s	remaining: 0us
# Training_column: 133
# 0:	learn: 0.7348033	total: 28.3ms	remaining: 11.3s
# 100:	learn: 0.6940246	total: 2.67s	remaining: 7.92s
# 200:	learn: 0.6880968	total: 5.23s	remaining: 5.18s
# 300:	learn: 0.6835648	total: 7.74s	remaining: 2.55s
# 399:	learn: 0.6793574	total: 10.5s	remaining: 0us
# Training_column: 134
# 0:	learn: 1.7759725	total: 27.7ms	remaining: 13.8s
# 100:	learn: 1.2154586	total: 3.41s	remaining: 13.5s
# 200:	learn: 1.1652191	total: 6.16s	remaining: 9.17s
# 300:	learn: 1.1384456	total: 8.55s	remaining: 5.66s
# 400:	learn: 1.1191147	total: 10.9s	remaining: 2.7s
# 499:	learn: 1.1038398	total: 13.3s	remaining: 0us
# Training_column: 135
# 0:	learn: 0.9397048	total: 27.7ms	remaining: 11s
# 100:	learn: 0.8691725	total: 2.61s	remaining: 7.73s
# 200:	learn: 0.8620371	total: 5.16s	remaining: 5.11s
# 300:	learn: 0.8558482	total: 8.1s	remaining: 2.66s
# 399:	learn: 0.8499284	total: 10.6s	remaining: 0us
# Training_column: 136
# 0:	learn: 2.8182868	total: 29.3ms	remaining: 14.6s
# 100:	learn: 1.8836204	total: 2.69s	remaining: 10.6s
# 200:	learn: 1.8042636	total: 5.25s	remaining: 7.81s
# 300:	learn: 1.7645586	total: 7.88s	remaining: 5.21s
# 400:	learn: 1.7328562	total: 10.9s	remaining: 2.68s
# 499:	learn: 1.7063341	total: 13.4s	remaining: 0us
# Training_column: 137
# 0:	learn: 1.3422823	total: 25.3ms	remaining: 12.6s
# 100:	learn: 1.0067532	total: 2.81s	remaining: 11.1s
# 200:	learn: 0.9862860	total: 5.26s	remaining: 7.82s
# 300:	learn: 0.9723822	total: 8.47s	remaining: 5.6s
# 400:	learn: 0.9608692	total: 10.9s	remaining: 2.69s
# 499:	learn: 0.9504502	total: 13.6s	remaining: 0us
# Training_column: 138
# 0:	learn: 2.6411251	total: 27.8ms	remaining: 13.9s
# 100:	learn: 1.5082842	total: 3s	remaining: 11.8s
# 200:	learn: 1.4661993	total: 5.44s	remaining: 8.09s
# 300:	learn: 1.4400166	total: 7.89s	remaining: 5.22s
# 400:	learn: 1.4178977	total: 10.3s	remaining: 2.55s
# 499:	learn: 1.3998175	total: 12.8s	remaining: 0us
# Training_column: 139
# 0:	learn: 2.4436847	total: 29.5ms	remaining: 11.8s
# 100:	learn: 1.9771091	total: 2.76s	remaining: 8.17s
# 200:	learn: 1.9333058	total: 5.71s	remaining: 5.65s
# 300:	learn: 1.9093351	total: 8.32s	remaining: 2.74s
# 399:	learn: 1.8905347	total: 10.9s	remaining: 0us

# %%
if SUBMIT:
    del df, X, Y, Xt
    for col in df_test.columns:
        if col in x_cols:
            del df_test[col]
    gc.collect()

# %%
# Export predictions to file.
if SUBMIT:
    export_file_results = 'results_cite.ftr'
    df_test.to_feather(export_file_results)
